# %%
# The workhorses
import numpy as np
import pandas as pd
import scipy.optimize
import scipy.special

# Plotting modules
import matplotlib.pyplot as plt

# This is to enable inline displays for the purposes of the tutorial
# %matplotlib inline

# This enables SVG graphics inline
# %config InlineBackend.figure_formats = {'png', 'retina'}

# Seaborn makes plots look nice
import seaborn as sns
sns.set_context('notebook', font_scale=1.5, rc={'lines.linewidth': 2.5})
sns.set_style('darkgrid', {'axes.facecolor': '(0.875, 0.875, 0.9)'})

# %%
#read in the dataset
AerobicIntensity = pd.read_csv("data/chure/20151001_aerobic_mean_intensities.csv",comment="#")
AnaerobicIntensity = pd.read_csv("data/chure/20151001_anaerobic_mean_intensities.csv", comment="#")

# %%
#change column names to make melting easier
AerobicIntensity.columns = ["0", "1e1", "1e2", "1e3", "1e4", "1e5"]
AnaerobicIntensity.columns = ["0", "1e1", "1e2", "1e3", "1e4", "1e5"]

# %%
#melt untidy data to create tidy dataframes
CleanAerobic = pd.melt(AerobicIntensity, var_name="PlasmidsPerCell", value_name= "MeanPixel").dropna()

CleanAnaerobic = pd.melt(AnaerobicIntensity, var_name="PlasmidsPerCell", value_name= "MeanPixel").dropna()

# %%
fig, ax = plt.subplots()
ax=plt.hist(np.log(CleanAerobic["MeanPixel"]),bins=200, range=[np.log(75),np.log(150)])

# %%
plt.plot(CleanAerobic[CleanAerobic["PlasmidsPerCell"]=="1e5"].MeanPixel)
plt.plot(CleanAerobic[CleanAerobic["PlasmidsPerCell"]=="1e4"].MeanPixel)
plt.legend(labels=["1e5","1e4"])

# %%
np.median(CleanAerobic["MeanPixel"])
# Out:
# 107.10344827586206

# %%
CleanAerobic.describe()
# Out:
#           MeanPixel
# count  38963.000000
# mean     124.216785
# std       65.094141
# min      101.562162
# 25%      105.224154
# 50%      107.103448
# 75%      109.855514
# max     1711.900662

# %%
np.max(CleanAerobic[CleanAerobic["PlasmidsPerCell"]=="0"].MeanPixel)
# Out:
# 111.99305555555556

# %%
np.min(CleanAerobic[CleanAerobic["PlasmidsPerCell"]=="1e1"].MeanPixel)
# Out:
# 101.81395348837208

# %%
CleanAerobic[CleanAerobic["PlasmidsPerCell"]=="1e1"].describe()
# Out:
#          MeanPixel
# count  7451.000000
# mean    107.345764
# std       9.072435
# min     101.813953
# 25%     104.941926
# 50%     106.547421
# 75%     107.982902
# max     380.230634

# %% [markdown]
# 112 is our cut-off. Elena has an explanation.

# %%
Nt = CleanAerobic[CleanAerobic["MeanPixel"]>112.0]

# %%
Nt.describe()
# Out:
#          MeanPixel
# count  7314.000000
# mean    200.604182
# std     123.984582
# min     112.002195
# 25%     119.432330
# 50%     154.182840
# 75%     234.802118
# max    1711.900662

# %% [markdown]
# **Part b:**

# %% [markdown]
# do it yourself.

# %% [markdown]
# **Part c:**

# %% [markdown]
# Derivation in Shashank's notebook.

# %% [markdown]
# **Question 2:**

# %% [markdown]
# Why Gaussian?
#
# Since the cells that are expressing the reporter construct are a sample from all the cells that are present in the embryo, it is fair to assume that the expression levels are Gaussian distributed (central limit theorem).
# As far as the background goes, they are relying on the expression of a reporter construct that can be variably expressed (comment on mosaicism in early drosophila embryos).
# Hence Gaussian +noise.
